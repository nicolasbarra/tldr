# %%
import numpy as np
import pandas as pd
import glob

# %%
results_df = pd.read_csv('sentences_with_votes.csv')
print(results_df.shape)
results_df.head()
# Out:
# (940, 7)
#   article_id                                       article_name  \
# 0   Article1  Netanyahu, Gantz, and Five Scenarios for the I...
# 1   Article1  Netanyahu, Gantz, and Five Scenarios for the I...
# 2   Article1  Netanyahu, Gantz, and Five Scenarios for the I...
# 3   Article1  Netanyahu, Gantz, and Five Scenarios for the I...
# 4   Article1  Netanyahu, Gantz, and Five Scenarios for the I...
#
#    sentence_order                                           sentence hit_id  \
# 0               0  Netanyahu, Gantz, and Five Scenarios for the I...   HIT1
# 1               1  The two continue to run neck and neck in the r...   HIT2
# 2               2  But both are running with a bloc of smaller pa...   HIT3
# 3               3  The President typically bestows a mandate to f...   HIT4
# 4               4  That is how Netanyahu won in 2009, and it’s wh...   HIT5
#
#   worker_id  is_relevant
# 0   Worker1            1
# 1   Worker2            0
# 2   Worker3            0
# 3   Worker4            0
# 4   Worker5            0

# %%
from collections import Counter

counts = Counter()
maxVotes = Counter()

#columns = [col for col in results_df.columns if 'Sentence' in col]

for index, row in results_df.iterrows():
  #for col in columns: 
    is_relevant = row['is_relevant']
    sentence = (row['article_id'], row['sentence_order'], row['sentence'])
    article = row['article_id']
    #sentence = row[col]
    if is_relevant == 1:
      counts[sentence] += 1
    else:
      counts[sentence] += 0
    if counts[sentence] >= maxVotes[article]:
      maxVotes[article] = counts[sentence]

print(counts)
# Out:
# Counter({('Article1', 0, 'Netanyahu, Gantz, and Five Scenarios for the Israeli Election Bernard Avishai If the final polls on the Israeli election are to be believed—by law, there will be no more revealed before the voting begins, on Tuesday morning—things are looking better for Prime Minister Benjamin Netanyahu’s Likud Party than for Blue and White, the new centrist party led by the former military Chief of Staff Benny Gantz.'): 10, ('Article1', 17, 'Consider the head-spinning possibilities: Gantz wins outright—and his problems begin.'): 10, ('Article1', 18, 'For Blue and White to win a plurality, a significant number of secular, formerly right-of-center voters will have to support it.'): 10, ('Article1', 47, 'Netanyahu is facing indictments.'): 10, ('Article1', 64, 'Netanyahu wins narrowly—and faces a Likud revolt.'): 10, ('Article1', 65, 'If Netanyahu’s bloc does win only a bare majority, his ability to form a government won’t be much better than Gantz’s.'): 10, ('Article1', 86, 'Netanyahu’s proceedings are in the way, however.'): 10, ('Article1', 88, 'The only way that he could be moved aside is if Rivlin, who has long been alienated from him, consults with all parties, concedes a virtual tie, and turns to a third member of the Knesset—say, a veteran Likud rival such as Sa’ar—and asks that member to assemble a coalition.'): 10, ('Article1', 90, 'There is much to learn from this campaign, none of it reassuring.'): 10, ('Article1', 30, 'So Gantz would be trapped.'): 9, ('Article1', 40, 'Gantz seems to be counting on eating his Zionist cake while depending on those who would not have it.'): 9, ('Article1', 57, 'Netanyahu’s way around this is to form a coalition that will urgently pass two laws.'): 9, ('Article1', 59, 'In effect, Netanyahu would be putting himself above the law.'): 9, ('Article1', 73, 'This is a radical possibility that may appear less so as the post-election dust settles.'): 9, ('Article1', 75, 'Indeed, in ordinary years, such a government would seem irresistible.'): 9, ('Article1', 77, 'The President, Reuven Rivlin, concerned about the integrity of civil society and its judicial institutions, is reported to be entertaining this idea.'): 9, ('Article1', 85, 'A unity government is installed.'): 9, ('Article1', 91, 'Like Trump’s supporters, Netanyahu’s often seem to so deeply identify with his everyman posturing, his regional bullying, and his nationalist resentments that democratic institutions can be made to appear as just another élitist preoccupation.'): 9, ('Article1', 20, 'This is a tall order: to most Israelis, the business sector seems strong, as does the deterrence of enemies, and Netanyahu gets credit for both.'): 8, ('Article1', 46, 'Netanyahu wins outright—and saves himself.'): 8, ('Article1', 58, 'The first, already pending in various versions, would give the Knesset the right to overturn, by a simple majority, any Supreme Court decision that strikes down an existing law as unconstitutional; the second would make it illegal to indict a sitting Prime Minister, as opposed to an ordinary minister.'): 8, ('Article1', 72, 'A unity government is negotiated.'): 8, ('Article1', 78, 'It’s hard to believe that a vast majority of voters for both parties wouldn’t see it as a relief.'): 8, ('Article1', 13, 'So Gantz’s bloc could squeak out a win.'): 2, ('Article1', 16, 'In fact, the polls reveal little about the serious difficulties that either of them, even with a clear win, will face in forming a government.'): 2, ('Article1', 23, 'Gantz and his allies have been courting these secular, security-minded voters, promising to provide a hard line on security—three of the four senior leaders of Blue and White are former generals—and that he will form a government only with Zionist (read: non-Arab) parties.'): 2, ('Article1', 24, 'He is also stressing the importance of the rule of law, warning of Netanyahu’s alliance with messianists and proto-fascist followers of the late Rabbi Meir Kahane—of the danger that Netany ...

# %%
final_df = pd.DataFrame.from_dict(counts, orient='index')

dict_list = []

for index, row in final_df.iterrows():
  dict_list.append ( 
    {
    'article_id': row.name[0],
    'sentence_order': row.name[1],
    'sentence': row.name[2],
    'votes': row[0],
    'max_votes': maxVotes[row.name[0]],     
    'agreement': row[0] / maxVotes[row.name[0]] * 100      
    }
  )
 
transform_df = pd.DataFrame.from_dict(dict_list)

print(transform_df)

transform_df.to_csv("output.csv")
# Out:
#     agreement article_id  max_votes  \
# 0       100.0   Article1         10
# 1        10.0   Article1         10
# 2        10.0   Article1         10
# 3        10.0   Article1         10
# 4         0.0   Article1         10
# 5         0.0   Article1         10
# 6         0.0   Article1         10
# 7        10.0   Article1         10
# 8        10.0   Article1         10
# 9        10.0   Article1         10
# 10        0.0   Article1         10
# 11       10.0   Article1         10
# 12        0.0   Article1         10
# 13       20.0   Article1         10
# 14       10.0   Article1         10
# 15        0.0   Article1         10
# 16       20.0   Article1         10
# 17      100.0   Article1         10
# 18      100.0   Article1         10
# 19       10.0   Article1         10
# 20       80.0   Article1         10
# 21        0.0   Article1         10
# 22       10.0   Article1         10
# 23       20.0   Article1         10
# 24       20.0   Article1         10
# 25       20.0   Article1         10
# 26       20.0   Article1         10
# 27       10.0   Article1         10
# 28       10.0   Article1         10
# 29       10.0   Article1         10
# ..        ...        ...        ...
# 64      100.0   Article1         10
# 65      100.0   Article1         10
# 66       20.0   Article1         10
# 67       10.0   Article1         10
# 68       10.0   Article1         10
# 69        0.0   Article1         10
# 70        0.0   Article1         10
# 71       10.0   Article1         10
# 72       80.0   Article1         10
# 73       90.0   Article1         10
# 74       10.0   Article1         10
# 75       90.0   Article1         10
# 76        0.0   Article1         10
# 77       90.0   Article1         10
# 78       80.0   Article1         10
# 79       10.0   Article1         10
# 80       10.0   Article1         10
# 81       20.0   Article1         10
# 82       10.0   Article1         10
# 83       20.0   Article1         10
# 84       20.0   Article1         10
# 85       90.0   Article1         10
# 86      100.0   Article1         10
# 87       10.0   Article1         10
# 88      100.0   Article1         10
# 89       20.0   Article1         10
# 90      100.0   Article1         10
# 91       90.0   Article1         10
# 92       10.0   Article1         10
# 93       20.0   Article1         10
#
#                                              sentence  sentence_order  votes
# 0   Netanyahu, Gantz, and Five Scenarios for the I...               0     10
# 1   The two continue to run neck and neck in the r...               1      1
# 2   But both are running with a bloc of smaller pa...               2      1
# 3   The President typically bestows a mandate to f...               3      1
# 4   That is how Netanyahu won in 2009, and it’s wh...               4      0
# 5   A majority of voters are now either hoping tha...               5      0
# 6   In a recent Channel 12 poll, fifty-eight per c...               6      0
# 7      But only thirty-six per cent wanted him to be.               7      1
# 8   Given the quirks of the Israeli electoral syst...               8      1
# 9   The margin of error is around four per cent, w...               9      1
# 10  Each must win three and a quarter per cent of ...              10      0
# 11  Fully seven parties—two in Gantz’s potential b...              11      1
# 12  Moreover, according to an April 2nd poll, more...              12      0
# 13            So Gantz’s bloc could squeak out a win.              13      2
# 14           Or Netanyahu’s could win in a landslide.              14      1
# 15  Or either leader could win a plurality for his...              15      0
# 16  In fact, the polls reveal little about the ser...              16      2
# 17  Consider the head-spinning possibilities: Gant...              17     10
# 18  For Blue and White to win a plurality, a signi...              18     10
# 19  So will a significant number of young first-ti...              19      1
# 20  This is a tall order: to most Israelis, the bu...              20      8
# 21         So even young Israelis tend to skew right.              21      0
# 22  A poll conducted by the Israel Democracy Insti...              22      1
# 23  Gantz and his allies have been courting these ...              23      2
# 24  He is also stressing the importance of the rul...              24      2
# 25  He is presenting himself as a return to an ecl...              25      2
# 26  Blue and White’s winning a majority bloc is an...              26      2
# 27  For that, it will have to hold its own without...              27      1
# 28  More important, Gantz will need the Arab vote ...              28      1
# 29  But the polls anticipate a decline in the Arab...              29      1
# ..                                                ...             ...    ...
# 64  Netanyahu wins narrowly—and faces a Likud revolt.              64     10
# 65  If Netanyahu’s bloc does win only a bare major...              65     10
# 66  Smaller, extremist parties would have the leve...              66      2
# 67  They could also preëmpt any consideration of t...              67      1
# 68  In either case, senior Likud leaders—for examp...              68      1
# 69  Moshe Kahlon, whose support Netanyahu may need...              69      0
# 70  Either man might inherit the Likud’s leadershi...              70      0
# 71  The former Prime Minister Ehud Olmert, an expe...              71      1
# 72                  A unity government is negotiated.              72      8
# 73  This is a radical possibility that may appear ...              73      9
# 74  If Netanyahu’s pending indictments were not a ...              74      1
# 75  Indeed, in ordinary years, such a government w...              75      9
# 76  It might entail a rotation agreement—as Labor ...              76      0
# 77  The President, Reuven Rivlin, concerned about ...              77      9
# 78  It’s hard to believe that a vast majority of v...              78      8
# 79              Gantz’s animus for Netanyahu is real.              79      1
# 80  But he was secretly recorded saying that “the ...              80      1
# 81  This might be interpreted as wanting to wait u...              81      2
# 82  Other arrangements might become plausible as t...              82      1
# 83  Blue and White leaders might break away and jo...              83      2
# 84  Rationalizations, from both sides, would not b...              84      2
# 85                   A unity government is installed.              85      9
# 86   Netanyahu’s proceedings are in the way, however.              86     10
# 87  And it is hard to see how any unity government...              87      1
# 88  The only way that he could be moved aside is i...              88     10
# 89  The move would be unprecedented, and it would ...              89      2
# 90  There is much to learn from this campaign, non...              90     10
# 91  Like Trump’s supporters, Netanyahu’s often see...              91      9
# 92  The Passover Haggadah, which will be read in a...              92      1
# 93                  Netanyahu has grasped the lesson.              93      2
#
# [94 rows x 6 columns]
